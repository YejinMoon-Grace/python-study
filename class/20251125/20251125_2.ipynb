# %%
import pandas as pd

# %%
df = pd.read_csv("./국립암센터_암발생 통계 정보_20250108.csv")

# %%
df
# Out:
#             발생연도    성별                 국제질병분류    암종     연령군    발생자수   조발생률
# 0           1999  남녀전체        00. All cancers   모든암  00-04세     539   16.1
# 1           1999  남녀전체        00. All cancers   모든암  05-09세     297    8.6
# 2           1999  남녀전체        00. All cancers   모든암  10-14세     306    9.6
# 3           1999  남녀전체        00. All cancers   모든암  15-19세     528   13.2
# 4           1999  남녀전체        00. All cancers   모든암  20-24세     720   18.4
# ...          ...   ...                    ...   ...     ...     ...    ...
# 35620  1999-2022    여자  24. All other cancers  기타 암  70-74세   19745   96.7
# 35621  1999-2022    여자  24. All other cancers  기타 암  75-79세   21422  136.3
# 35622  1999-2022    여자  24. All other cancers  기타 암  80-84세   18511  178.9
# 35623  1999-2022    여자  24. All other cancers  기타 암   85세이상   16793  220.2
# 35624  1999-2022    여자  24. All other cancers  기타 암    연령전체  168118   28.2
#
# [35625 rows x 7 columns]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape
# Out:
# (35625, 7)

# %%
df.head(3)
# Out:
#    발생연도    성별           국제질병분류   암종     연령군  발생자수  조발생률
# 0  1999  남녀전체  00. All cancers  모든암  00-04세   539  16.1
# 1  1999  남녀전체  00. All cancers  모든암  05-09세   297   8.6
# 2  1999  남녀전체  00. All cancers  모든암  10-14세   306   9.6

# %%
type(df['발생연도'])
# Out:
# pandas.core.series.Series

# %%
type(df['발생연도'].values)
# Out:
# numpy.ndarray

# %%
import numpy as np

vector = np.array([1, 2, 3, 4, 5])

# %%
vector * 5
# Out:
# array([ 5, 10, 15, 20, 25])

# %%
type(df.iloc[0, :])
# Out:
# pandas.core.series.Series

# %%
df.iloc[0, :].values
# Out:
# array(['1999', '남녀전체', '00. All cancers', '모든암', '00-04세', np.int64(539),
#        np.float64(16.1)], dtype=object)

# %%
# !pip install scipy
# Out:
# Collecting scipy
#   Downloading scipy-1.13.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
# Requirement already satisfied: numpy<2.3,>=1.22.4 in /home/kdt_43/miniconda3/lib/python3.9/site-packages (from scipy) (2.0.2)
# Downloading scipy-1.13.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (38.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.6/38.6 MB 28.3 MB/s  0:00:01 eta 0:00:01
# Installing collected packages: scipy
# Successfully installed scipy-1.13.1

# %%
import scipy

# %%
data = np.array(range(10)) + 1

# %%
data.var()
# Out:
# np.float64(8.25)

# %%
pd.DataFrame(data).var()
# Out:
# 0    9.166667
# dtype: float64

# %%
data.std()
# Out:
# np.float64(2.8722813232690143)

# %%
pd.DataFrame(data).std()
# Out:
# 0    3.02765
# dtype: float64

# %% [markdown]
# 값이 다른 이유는 numpy는 수학적으로 접근해서 분산을 구해서, data.std()는 자유도가 없이 그냥 계산해서 그럼.
#
# 둘이 생각하는게 달라서 그런거라고 생각하면됨.

# %%
0.1 + 0.2
# Out:
# 0.30000000000000004

# %%
df.loc[1:3, ['발생연도', '암종']]
# Out:
#    발생연도   암종
# 1  1999  모든암
# 2  1999  모든암
# 3  1999  모든암

# %%
def get_ab(a, b):
    return a + b

# %%
get_ab(10, 20)
# Out:
# 30

# %%
(lambda a, b : a + b)(10, 20)
# Out:
# 30

# %%
df
# Out:
#             발생연도    성별                 국제질병분류    암종     연령군    발생자수   조발생률
# 0           1999  남녀전체        00. All cancers   모든암  00-04세     539   16.1
# 1           1999  남녀전체        00. All cancers   모든암  05-09세     297    8.6
# 2           1999  남녀전체        00. All cancers   모든암  10-14세     306    9.6
# 3           1999  남녀전체        00. All cancers   모든암  15-19세     528   13.2
# 4           1999  남녀전체        00. All cancers   모든암  20-24세     720   18.4
# ...          ...   ...                    ...   ...     ...     ...    ...
# 35620  1999-2022    여자  24. All other cancers  기타 암  70-74세   19745   96.7
# 35621  1999-2022    여자  24. All other cancers  기타 암  75-79세   21422  136.3
# 35622  1999-2022    여자  24. All other cancers  기타 암  80-84세   18511  178.9
# 35623  1999-2022    여자  24. All other cancers  기타 암   85세이상   16793  220.2
# 35624  1999-2022    여자  24. All other cancers  기타 암    연령전체  168118   28.2
#
# [35625 rows x 7 columns]

# %%
df['성별'].unique()
# Out:
# array(['남녀전체', '남자', '여자'], dtype=object)

# %%
df['성별'].apply(lambda x : 'x' if x == "남녀전체" else x)
# Out:
# 0         x
# 1         x
# 2         x
# 3         x
# 4         x
#          ..
# 35620    여자
# 35621    여자
# 35622    여자
# 35623    여자
# 35624    여자
# Name: 성별, Length: 35625, dtype: object

# %%
def tmp(x):
    if x == "남녀전체":
        return '9'
    else:
        return x

# %%
df['성별']
# Out:
# 0        남녀전체
# 1        남녀전체
# 2        남녀전체
# 3        남녀전체
# 4        남녀전체
#          ...
# 35620      여자
# 35621      여자
# 35622      여자
# 35623      여자
# 35624      여자
# Name: 성별, Length: 35625, dtype: object
