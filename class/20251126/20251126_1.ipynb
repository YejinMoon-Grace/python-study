# %%
import pandas as pd

# %%
dir(pd)

# %%
help(pd.read_csv)
# Out:
# Help on function read_csv in module pandas.io.parsers.readers:
#
# ...

# %%
# encoding -> 완성형
cp949, euc-kr

# utf-8

# %%
df = pd.read_csv("./국립암센터_암발생 통계 정보_20250108.csv", encoding='utf-8')

# %%
ord('A')
# Out:
# 65

# %%
ord('a')
# Out:
# 97

# %%
df.tail(1)
# Out:
#             발생연도  성별                 국제질병분류    암종   연령군    발생자수  조발생률
# 35624  1999-2022  여자  24. All other cancers  기타 암  연령전체  168118  28.2

# %%
df.shape
# Out:
# (35625, 7)

# %%
# 결측치
df.isnull().sum()
# Out:
# 발생연도         0
# 성별           0
# 국제질병분류       0
# 암종           0
# 연령군          0
# 발생자수         0
# 조발생률      5763
# dtype: int64

# %%
df.shape
# Out:
# (35625, 7)

# %%
df.dropna().shape
# Out:
# (29862, 7)

# %%
df.shape
# Out:
# (35625, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35625 entries, 0 to 35624
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   발생연도    35625 non-null  object
#  1   성별      35625 non-null  object
#  2   국제질병분류  35625 non-null  object
#  3   암종      35625 non-null  object
#  4   연령군     35625 non-null  object
#  5   발생자수    35625 non-null  int64
#  6   조발생률    29862 non-null  float64
# dtypes: float64(1), int64(1), object(5)
# memory usage: 1.9+ MB

# %%
import numpy as np

# %%
pd.DataFrame({'a' : [1,2,3,4, np.nan, None ]}).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   a       4 non-null      float64
# dtypes: float64(1)
# memory usage: 180.0 bytes

# %%
df.describe()
# Out:
#                발생자수          조발생률
# count  3.562500e+04  29862.000000
# mean   2.098783e+03     61.440684
# std    3.391913e+04    224.064298
# min    0.000000e+00      0.000000
# 25%    4.000000e+00      1.200000
# 50%    7.200000e+01      7.200000
# 75%    4.120000e+02     31.000000
# max    4.673073e+06   3259.400000

# %%
df.describe(include='all')
# Out:
#          발생연도     성별           국제질병분류     암종     연령군          발생자수  \
# count   35625  35625            35625  35625   35625  3.562500e+04
# unique     25      3               25     25      19           NaN
# top      1999   남녀전체  00. All cancers    모든암  00-04세           NaN
# freq     1425  11875             1425   1425    1875           NaN
# mean      NaN    NaN              NaN    NaN     NaN  2.098783e+03
# std       NaN    NaN              NaN    NaN     NaN  3.391913e+04
# min       NaN    NaN              NaN    NaN     NaN  0.000000e+00
# 25%       NaN    NaN              NaN    NaN     NaN  4.000000e+00
# 50%       NaN    NaN              NaN    NaN     NaN  7.200000e+01
# 75%       NaN    NaN              NaN    NaN     NaN  4.120000e+02
# max       NaN    NaN              NaN    NaN     NaN  4.673073e+06
#
#                 조발생률
# count   29862.000000
# unique           NaN
# top              NaN
# freq             NaN
# mean       61.440684
# std       224.064298
# ...
