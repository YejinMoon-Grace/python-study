# %%
from melon import get_lyrics
    # 모듈
# 권장하지 않는 거
# from melon import *

# %%
get_lyrics('39166705')
# Out:
# /home/kdt_43/workspace/melon.py:16: GuessedAtParserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 16 of the file /home/kdt_43/workspace/melon.py. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#
#   bs = BeautifulSoup(lyrics)
# /home/kdt_43/workspace/melon.py:17: GuessedAtParserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# ...

# %%
import melon

# %%
melon.get_lyrics('39166705')
# Out:
# /home/kdt_43/workspace/melon.py:16: GuessedAtParserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 16 of the file /home/kdt_43/workspace/melon.py. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#
#   bs = BeautifulSoup(lyrics)
# /home/kdt_43/workspace/melon.py:17: GuessedAtParserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# ...

# %%
import requests 
from bs4 import BeautifulSoup
url = "https://www.melon.com/chart/index.htm"

# %%
head = {"user-agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/142.0.0.0 Safari/537.36 Edg/142.0.0.0"}

# %%
r = requests.get(url, headers=head)

# %%
bs = BeautifulSoup(r.text)

# %%
chart = bs.find("div", id="tb_list")

# %%
chart.find_all('tr', id="lst50")
# Out:
# [<tr class="lst50" data-song-no="600287375" id="lst50">
#  <td><div class="wrap t_right"><input class="input_check" name="input_check" title="Good Goodbye 곡 선택" type="checkbox" value="600287375"/></div></td>
#  <td><div class="wrap t_center"><span class="rank">1</span><span class="none">위</span></div></td>
#  <!-- 차트순위 추가 -->
#  <td><div class="wrap">
#  <span class="rank_wrap" title="순위 동일">
#  <span class="bullet_icons rank_static"><span class="none">순위 동일</span></span>
#  <span class="none">0</span>
#  </span>
#  </div></td>
#  <td><div class="wrap">
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('12160000');" title="Good Goodbye">
#  <img alt="Good Goodbye - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="https://cdnimg.melon.co.kr/cm2/album/images/121/60/000/12160000_20251014164646_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>
#  </div></td>
#  <td><div class="wrap">
# ...

# %%
chart.find_all('tr', id="lst50")[0].find('a', class_="btn button_icons type03 song_info")['href']
# Out:
# "javascript:melon.link.goSongDetail('600287375');"

# %%
import re 

p = re.compile("[\\d]+")
p.findall(chart.find_all('tr', id="lst50")[0].find('a', class_="btn button_icons type03 song_info")['href'])
# Out:
# ['600287375']

# %%
for x in chart.find_all('tr', id="lst50"):
    print(p.findall(x.find('a', class_="btn button_icons type03 song_info")['href']))
# Out:
# ['600287375']
# ['600243411']
# ['600299706']
# ['600513208']
# ['39166708']
# ['600354699']
# ['36397952']
# ['600359330']
# ['39298775']
# ['38733032']
# ['39156202']
# ['39307948']
# ['38429074']
# ['39166705']
# ['36730261']
# ['39566906']
# ['39721328']
# ['39693013']
# ['38104031']
# ['600032332']
# ['38242510']
# ['38626852']
# ['600024643']
# ['38300904']
# ['39430660']
# ['37228861']
# ['38123332']
# ['32061975']
# ['600318353']
# ['38123338']
# ['600057428']
# ['38071559']
# ['38388023']
# ['37323944']
# ['34061322']
# ['4446485']
# ['37390939']
# ['38426197']
# ['38629386']
# ['38120327']
# ['600320356']
# ['39051429']
# ['38635449']
# ['31927275']
# ['36699489']
# ['37901626']
# ['30962526']
# ['39765727']
# ['600035196']
# ['600552360']

# %%
chart_list50 = []
for x in chart.find_all('tr', id="lst50"):
    chart_list50.append(p.findall(x.find('a', class_="btn button_icons type03 song_info")['href'])[0])

# %%
chart_list50 = [p.findall(x.find('a', class_="btn button_icons type03 song_info")['href'])[0] for x in chart.find_all('tr', id="lst50")]

# %%
chart_list100 = [p.findall(x.find('a', class_="btn button_icons type03 song_info")['href'])[0] for x in chart.find_all('tr', id="lst100")]

# %%
import requests 
from bs4 import BeautifulSoup
def get_lyrics(song_id:str) -> dict:
    """
    song_id : 노래 ID
    return : {'title' : '노래제목', 'artist' : '가수', 'lyrics' : '가사'}
    """
    url = f"https://www.melon.com/song/detail.htm?songId={song_id}"
    head = {"user-agent" :
"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/142.0.0.0 Safari/537.36 Edg/142.0.0.0"}
    bs = BeautifulSoup(requests.get(url, headers=head).text, 'lxml')
    title = bs.find("div", class_="entry").find("div", class_="song_name").text.strip().replace("곡명", "").strip()
    artist = bs.find("div", class_="entry").find('a')['title']
    lyrics_txt = BeautifulSoup(str(bs.find("div", id="d_video_summary")).replace("<br/>", "\n")).text.strip()
    return {'title' : title, 'artist' : artist, 'lyrics' : lyrics_txt}

# %%
if __name__ == "__main__":
    print('test입니다.')
    print(get_lyrics('600035196'))
# Out:
# test입니다.
# {'title': '가만히 눈을 감고', 'artist': 'DK(디셈버)', 'lyrics': '아침이 와 눈을 떠보니\n그대의 작은 흔적이\n내 곁에 있어\n메마른 내 입술에 스친\n잊었던 하얀 숨결이 차가워져\n기억은 나누어지는지\n어쩌면 부서진 채 사라질까\n내일은 또 오게 되겠지\n세상은 여전한가 봐\n그댄 어떤가요\n\n언젠가 나를 슬프게 했던\n그대 울던 얼굴\n다시 나의 볼을 적시면\n지워버리려고 기도했던 날들\n내 마음이 내 눈물이\n그대를 기억하고 있어\n\nYour love forever\n가만히 눈을 감고\n그대를 그리네요\n손에 닿을 듯 가까이\n계절이 변해가듯\n무심히 내 영혼을\n지나쳐버린다 해도\n\n잊혀지는 기억이라도\n내게는 유일한 사랑\n내 전부인 걸\n긴 세월이 흐른뒤에도\n좋았던 추억만으로 가질게요\n\n여전히 우릴 비추고 있던\n어느 겨울 새벽\n별빛에 소원을 빌던 밤들과\n내게만 주었던 따스한 체온을\n내 마음이 내 눈물이 그대를 기억하고 있어\n\nI wish forever\n가만히 눈을 감고\n그대를 그리네요\n손에 닿을 듯 가까이\n계절이 변해가듯\n무심히 내 영혼을\n지나쳐버린다 해도\n\nAlways my love\nYour love is so everlasting my heart\nYou are my everything\n\nYour love forever\n가만히 눈을 감고\n그대를 그리네요\n손에 닿을 듯 가까이\n먼 길의 끝 즈음에서\n기다린 내 영혼을\n지나쳐버린다 해도\n\n이젠 기억에서만\n그대가 보이네요\n괜찮아요 난 이제\n내 것일 수 없지만\n버틸 수 있을 만큼\n내 안에 남았으니까\n아직은 남았으니까'}

# %%
# !python melon.py

# %%
import pickle 

with open("./melon.pkl", 'rb') as f:
    total = pickle.load(f)

# %%
total[2]
# Out:
# {'title': '타임캡슐',
#  'artist': '다비치',
#  'lyrics': '점점 지쳐만 가는 \n많이 무료한 날들 \n하루 끝의 나를 돌아보기도 싫어 \n나도 내가 아쉬워 \n꿈이라 어려워 그런 감각은 \n\n그러다 어느 날 나는 \n먼지 쌓인 서랍장을 열어보니 \n방긋하고 웃어버리며 \n이 타임캡슐 어릴 적 \n내가 쓴, 내게 쓴 말 한가득 \n\n곱게 접어 묻어둔 편지 한 장 \n느렸어도 즐겁던 거북이와 나 \n잠깐 멈춰 \n살짝 열어 \n한참 서서 시간을 잇다가\n\n어디까지 갔나요 \n또 어떤 어른이 됐나요 \n언젠가 내가 마주할 \n아주 먼 미래의 넌 \n그 꿈을 이루나요 난 \n\n어디 쯤에 온 걸까 \n나도 모르고 왔단 말이야 \n언제나 뭔갈 되뇌던\n아주 먼 과거의 기억 \n어떤 꿈을 꿨던 걸까 난\n\n어제의 나를 담은 일기장과는 \n달리 생각보다 훨씬 많이 당찬 \n환한 여정 \n활짝 펼쳐 \n나아가려던 꼬마 아이잖아 \n\n어디까지 갔나요 \n또 어떤 어른이 됐나요 \n언젠가 내가 마주할 \n아주 먼 미래의 넌 \n그 꿈을 이루나요 난 \n\n어디 쯤에 온 걸까 \n나도 모르고 왔단 말야 \n언제나 뭔갈 되뇌던 \n아주 먼 과거의 기억 \n어떤 꿈을 꿨던 걸까 난 \n\n먼지 쌓인 서랍과 남아있던 \n그 작았던 꼬만 자라있어 \n우리는 오늘 만난 거야 \n다시 가 볼게 \n네 손을 잡은 채 \n\n어디로 가 볼까요 \n어떤 삶이 되어볼까요 \n우리가 두 손 잡으면 \n다가올 미래에서 \n무엇도 두렵지 않아 \n\n어디도 못 갔지만 \n웅크려 있었던 것 뿐이야 \n이제 다시 툭툭 일어서 \n한 걸음 두 걸음 널 \n믿고서 난 걸어갈 거야\n\n널 보게 된 마지막\n우리가 만난 마지막'}

# %%
import pymysql
conn = pymysql.connect(host='127.0.0.1', user= 'kdt', password='123', port=3306)

cur = conn.cursor()

# %%
cur.execute("create database kdt")
# Out:
# 1

# %%
conn = pymysql.connect(host='127.0.0.1', user= 'kdt', password='123', port=3306, database="kdt")

cur = conn.cursor()

# %%
sql = """ 
CREATE TABLE kdt.melon_lyrics(
title varchar(200) not null ,
artist varchar(200) not null,
lyrics text
)
 """

# %%
cur.execute(sql)
# Out:
# 0

# %%
cur.execute('show tables')
cur.fetchall()
# Out:
# (('melon_lyrics',),)

# %%
for k, v in total[0].items():
    print(f"k:{k}, v: {v}")
# Out:
# k:title, v: Good Goodbye
# k:artist, v: 화사 (HWASA)
# k:lyrics, v: 나를 그냥 짓밟고 가
# 괜찮아 돌아보지 마
# 내가 아파봤자 너만 하겠니
# 이젠 너를 헤아려봐
#
# 날 위해 쉬던 그 숨은 잊고
# 저 위에 널 위해 just kill my ego
#
# 등 돌려 걸어가
# You got it you got it yeah
#
# 안녕은 우릴 아프게 하지만 우아할 거야
# 나 땅을 치고 후회하도록 넌 크게 웃어줘
# goodb-ye
#
# bye ye ye ye ye ye
# bye ye ye ye ye ye (b-ye)
# bye ye ye ye ye ye
# bye ye ye ye ye
# 후회하도록 goodb-ye
#
# 널 생각한 운율이야
# 비로소 느껴지잖아
# 눈물은 고이고 찬란하게 빛나
# 우린 좋은 안녕 중이야
#
# 고맙단 말 대신 전할게
# goodbye good goodbye
#
# 안녕은 우릴 아프게 하지만 우아할 거야
# 나 땅을 치고 후회하도록 넌 크게 웃어줘
# goodb-ye
#
# bye ye ye ye ye ye
# bye ye ye ye ye ye (b-ye)
# bye ye ye ye ye ye
# bye ye ye ye ye
#
# 세상이 나를 빤히 내려다봐도
# 내 편이 돼 줄 사람 하나 없어도
# Don't worry it's okay
# 난 내 곁에 있을게
# I'll be on my side instead of you
#
# 안녕은 나를 아프게 하지만 울어볼 거야
# 땅을 치고 후회해도 좋아 우리 이렇게
# goodb-ye
#
# bye ye ye ye ye ye
# bye ye ye ye ye ye (b-ye)
# bye ye ye ye ye ye
# bye ye ye ye ye
# 후회조차도 goodb-ye

# %%
sql = "insert into kdt.melon_lyrics values(%s, %s, %s)"

# %%
for i in range(len(total)):
    cur.execute(sql, [val for key, val in total[i].items()])
    conn.commit()

# %%
cur.execute("select title from melon_lyrics")
# Out:
# 100
