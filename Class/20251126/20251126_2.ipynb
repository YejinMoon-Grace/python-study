# %%
import pandas as pd
import pickle

# %%
kbo = pd.read_pickle("./kbo_detail.pkl")

# %%
kbo[['team','선수명']]
# Out:
#        team   선수명
# 0    한화 이글스   강재민
# 1    한화 이글스   권광민
# 2    한화 이글스   권동욱
# 3    한화 이글스    권현
# 4    한화 이글스   김강민
# ..      ...   ...
# 839   KT 위즈   한민우
# 840   KT 위즈   한차현
# 841   KT 위즈   홍현빈
# 842   KT 위즈   황의준
# 843   KT 위즈   황재균
#
# [844 rows x 2 columns]

# %%
kbo['신장' ] = kbo['신장/체중'].apply(lambda x : int(x.split("/")[0].replace("cm", "")))

# %%
kbo['체중' ] = kbo['신장/체중'].apply(lambda x : int(x.split("/")[1].replace("kg", "")))

# %%
kbo['BMI']  = kbo['체중' ] / (kbo['신장']/100)**2

# %%
kbo.sort_values(by='BMI', ascending=False).head()
# Out:
#       선수명     등번호            생년월일         포지션         신장/체중  \
# 10    김민우   No.53   1995년 07월 25일    투수(우투우타)   186cm/123kg
# 356   김범석   No.55   2004년 05월 21일    포수(우투우타)   178cm/110kg
# 30    박성웅   No.63   1999년 08월 20일    투수(좌투좌타)   178cm/109kg
# 57    이성원   No.98   1999년 11월 02일   내야수(우투우타)   185cm/115kg
# 509   김기연   No.45   1997년 09월 07일    포수(우투우타)   178cm/106kg
#
#                     경력    입단 계약금        연봉                 지명순위   입단년도  \
# 10         사파초-마산중-용마고   20000만원   16700만원    15 한화 2차 1라운드 1순위   15한화
# 356      김해삼성초-경남중-경남고   25000만원    3300만원       23 LG 1라운드 7순위   23LG
# 30     광주서석초-충장중-광주제일고   10000만원    3300만원   18 한화 2차 2라운드 14순위   18한화
# 57       수원신곡초-매향중-장안고    6000만원    3000만원   18 한화 2차 6라운드 54순위
# 509   광주수창초-진흥중-진흥고-LG    7000만원    4000만원   16 LG 2차 4라운드 34순위   17LG
#
#        team   신장   체중        BMI
# 10   한화 이글스  186  123  35.553243
# 356  LG 트윈스  178  110  34.717839
# 30   한화 이글스  178  109  34.402222
# 57   한화 이글스  185  115  33.601169
# 509  두산 베어스  178  106  33.455372

# %%
kbo.drop(['신장/체중'], axis=1, inplace=True)

# %%
kbo2 = kbo.groupby('team')[['신장', '체중']].mean()

# %%
kbo2.loc[ 'KIA 타이거즈' , :  ]
# Out:
# 신장    182.773810
# 체중     88.666667
# Name: KIA 타이거즈, dtype: float64

# %%
kbo2.loc[ 'KIA 타이거즈' , :  ]
# Out:
# 신장    182.773810
# 체중     88.666667
# Name: KIA 타이거즈, dtype: float64

# %%
kbo2.loc[ 'KIA 타이거즈':'SSG 랜더스' , '신장'  ]
# Out:
# team
# KIA 타이거즈    182.773810
# KT 위즈       182.103448
# LG 트윈스      182.986486
# NC 다이노스     183.146067
# SSG 랜더스     181.975309
# Name: 신장, dtype: float64

# %%
kbo2.iloc[2:4, 0]
# Out:
# team
# LG 트윈스     182.986486
# NC 다이노스    183.146067
# Name: 신장, dtype: float64

# %%
kbo.groupby('team')[['신장', '체중']].agg(['mean', 'median', 'min', 'max', 'var', 'std' ])
# Out:
#                   신장                                               체중         \
#                 mean median  min  max        var       std       mean median
# team
# KIA 타이거즈  182.773810  183.0  165  195  23.044607  4.800480  88.666667   87.0
# KT 위즈     182.103448  183.0  170  193  23.024058  4.798339  85.390805   85.0
# LG 트윈스    182.986486  183.0  171  194  26.177897  5.116434  87.270270   85.5
# NC 다이노스   183.146067  183.0  171  196  23.194331  4.816049  87.089888   86.0
# SSG 랜더스   181.975309  182.0  165  193  25.324383  5.032334  86.148148   88.0
# 고양 히어로즈   181.739130  182.0  173  188  13.928854  3.732138  84.347826   83.0
# 두산 베어스    183.166667  183.0  175  195  22.236948  4.715607  87.261905   88.5
# 롯데 자이언츠   183.282353  182.0  172  197  25.300280  5.029938  88.988235   88.0
# 삼성 라이온즈   182.482353  183.0  163  198  30.752661  5.545508  87.376471   87.0
# 키움 히어로즈   181.016949  181.0  169  194  26.534191  5.151135  87.288136   88.0
# 한화 이글스    182.473118  183.0  173  192  18.578074  4.310229  88.817204   89.0
#
#
#          min  max         var        std
# team
# KIA 타이거즈  68  108   77.502008   8.803522
# KT 위즈     68  107   68.357124   8.267837
# LG 트윈스    67  110   95.734173   9.784384
# NC 다이노스   69  115   61.969101   7.872046
# SSG 랜더스   65  108   76.027778   8.719391
# 고양 히어로즈   73  105   79.873518   8.937199
# 두산 베어스    68  106   81.834194   9.046225
# 롯데 자이언츠   72  118   79.202241   8.899564
# 삼성 라이온즈   62  113   91.761345   9.579214
# 키움 히어로즈   73  109   68.277615   8.263027
# 한화 이글스    65  123  103.498831  10.173438

# %%
kbo['경력'].apply(lambda x : x.split('-')[0]).value_counts().reset_index().rename(columns={'count' : '명'})
# Out:
#                경력   명
# 0           부산수영초  19
# 1             가동초  14
# 2             양정초  14
# 3             본리초  13
# 4           광주대성초  13
# ..            ...  ..
# 345   거제제산초(거제리틀)   1
# 346           영천초   1
# 347    양남초(하남시리틀)   1
# 348    신기초(금천구리틀)   1
# 349    홍연초(마포구리틀)   1
#
# [350 rows x 2 columns]

# %%
kbo[kbo['경력'].str.find("부산수영초") > -1]['team'].value_counts()
# Out:
# team
# 롯데 자이언츠     5
# 한화 이글스      3
# SSG 랜더스     3
# LG 트윈스      3
# KIA 타이거즈    1
# NC 다이노스     1
# 키움 히어로즈     1
# 두산 베어스      1
# 삼성 라이온즈     1
# Name: count, dtype: int64

# %%
kbo['생년월일'][0]
# Out:
# ' 1997년 04월 03일'

# %%
from datetime import date, datetime
kbo['생년월일'] = kbo['생년월일'].apply(lambda x : datetime.strptime(x.replace(" ", ""), "%Y년%m월%d일"))

# %%
(datetime.now() - kbo['생년월일'][0])
# Out:
# Timedelta('10464 days 14:25:59.893788')

# %%
kbo['생년월일'][0].year
# Out:
# 1997

# %%
# 현재 야구선수들은 태어나서 몇일 살았나?
# 나이

# %%
kbo['생년월일'].apply(lambda x : (datetime.now() - x).days)
# Out:
# 0      10464
# 1      10211
# 2       9088
# 3       7581
# 4      15780
#        ...
# 839     9710
# 840     9858
# 841    10316
# 842     8635
# 843    14001
# Name: 생년월일, Length: 844, dtype: int64

# %%
kbo.sort_values(by=['신장'], ascending=False).groupby(['team']).first()
# Out:
#            선수명      등번호       생년월일        포지션  \
# team
# KIA 타이거즈   홍원빈   No.021 2000-10-16   투수(우투우타)
# KT 위즈      이준명   No.101 2002-12-18   투수(우투우타)
# 841   홍현빈    No.31 1997-08-29   외야수(우투좌타)               수원신곡초-매송중-유신고-KT-상무
# 842   황의준   No.103 2002-04-06   외야수(우투좌타)                   칠성초-경복중-경북고-수성대
# 843   황재균    No.10 1987-07-28   내야수(우투우타)   사당초-서울이수중-경기고-현대-히어로즈-롯데-샌프란시스코
#
#        입단 계약금         연봉                 지명순위      입단년도    team   신장   체중  \
# 0      8000만원    14500만원   20 한화 2차 4라운드 38순위      20한화  한화 이글스  180   89
# 1                 3300만원   22 한화 2차 5라운드 41순위   16시카고컵스  한화 이글스  189  102
# 2                 3000만원           24 한화 육성선수            한화 이글스  173   85
# 3      3000만원     3000만원     24 한화 10라운드 91순위            한화 이글스  182   88
# 4     11000만원    11000만원   01 SK 2차 2라운드 18순위      01SK  한화 이글스  182   87
# ..        ...        ...                  ...       ...     ...  ...  ...
# 839    1000만원     3000만원           23 KT 육성선수             KT 위즈  177   82
# 840   10000만원     3100만원   21 KT 2차 2라운드 15순위      21KT   KT 위즈  180   80
# 841    9000만원     4500만원   17 KT 2차 3라운드 21순위      17KT   KT 위즈  174   70
# 842    4000만원     3000만원      23 KT 8라운드 80순위             KT 위즈  185   95
# 843    6000만원   100000만원   06 현대 2차 3라운드 24순위      06현대   KT 위즈  183   96
#
#            BMI
# 0    27.469136
# 1    28.554632
# 2    28.400548
# 3    26.566840
# 4    26.264944
# ..         ...
# 839  26.173833
# 840  24.691358
# 841  23.120624
# 842  27.757487
# 843  28.666129
#
# [844 rows x 13 columns]

# %%
import requests

# %%
url = "https://www.kebhana.com/cms/rate/wpfxd651_01i_01.do"

# %%
payload = {"ajax":"true",
"pbldDvCd":"0",
"inqStrDt":"20251126",
"inqKindCd":"1",
"requestTarget":"searchContentDiv"}

# %%
exchange = pd.read_html(requests.post(url, data=payload).text)[0]
# Out:
# /tmp/ipykernel_58613/3789694309.py:1: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   exchange = pd.read_html(requests.post(url, data=payload).text)[0]

# %%
for x in exchange.columns:
  print("_".join(sorted(list(set(x)))))
# Out:
# 통화
# 사실 때_현찰_환율
# Spread_사실 때_현찰
# 파실 때_현찰_환율
# Spread_파실 때_현찰
# 보낼 때_송금
# 받을 때_송금
# 외화 수표 파실때
# 매매 기준율
# 환가 료율
# 미화 환산율

# %%
exchange.columns = ["_".join(sorted(list(set(x)))) for x in exchange.columns]

# %%
master = {x[0] : x[1] for x in exchange['통화'].str.split().values}

# %%
# get_exchange
# 날짜, 나라명

# %%
def get_exchange( date_, country='미국'):
  """
  date_ : 환율 날짜(YYYYMMDD)
  country : 국가
  return : 환율
  """
  url = "https://www.kebhana.com/cms/rate/wpfxd651_01i_01.do"
  payload = {"ajax":"true",
            "pbldDvCd":"0",
            "inqStrDt":"20251126",
            "inqKindCd":"1",
            "requestTarget":"searchContentDiv"}
  exchange = pd.read_html(requests.post(url, data=payload).text)[0]
  exchange.columns = ["_".join(sorted(list(set(x)))) for x in exchange.columns]
  master = {x[0] : x[1] for x in exchange['통화'].str.split().values}
  return float(exchange[exchange.통화.str.find(country) > -1]['사실 때_현찰_환율'].values[0])

# %%
get_exchange("20251126", '일본')
# Out:
# /tmp/ipykernel_58613/675833430.py:13: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   exchange = pd.read_html(requests.post(url, data=payload).text)[0]
# 955.35
